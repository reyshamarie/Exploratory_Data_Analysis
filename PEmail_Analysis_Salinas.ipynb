# %% [markdown]
# <a href="https://colab.research.google.com/github/reyshamarie/Exploratory_Data_Analysis/blob/main/PEmail_Analysis_Salinas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install mailbox
# Out:
# Requirement already satisfied: mailbox in /usr/local/lib/python3.10/dist-packages (0.4)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import mailbox
mboxfile = "gdrive/My Drive/Colab Notebooks/mbox/AllmailSpamandTrash.mbox"


mbox = mailbox.mbox(mboxfile)
mbox

# %%
for msg in mbox:
  # Print all keys for each message
  for key in msg.keys():
    print(key)
# Out:
# Streaming output truncated to the last 5000 lines.
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# References
# In-Reply-To
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Track-Opens
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Report-Abuse-To
# Feedback-Id
# X-Mailer
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# X-Account-Notification-Type
# Feedback-ID
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# X-MSFBL
# DKIM-Signature
# To
# Message-ID
# Date
# Content-Type
# MIME-Version
# Reply-To
# X-Campaign-ID
# From
# Subject
# X-Message-ID
# X-Feedback-ID
# Feedback-ID
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Sender
# Date
# Mime-Version
# Subject
# From
# To
# X-Mailgun-Drop-Message
# Message-Id
# Content-Transfer-Encoding
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# X-Account-Notification-Type
# Feedback-ID
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# References
# In-Reply-To
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Feedback-ID
# X-GoogleForms-FormId
# X-GoogleForms-CustomerDisplayName
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# References
# In-Reply-To
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# References
# In-Reply-To
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Sender
# Return-Path
# Date
# From
# Reply-To
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailgun-Tag
# X-Mailgun-Variables
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# References
# In-Reply-To
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# References
# In-Reply-To
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Forwarded-Encrypted
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Forwarded-Encrypted
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Reply-To
# X-No-Auto-Attachment
# References
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailgun-Dkim
# X-Mailer
# X-Report-Abuse-To
# Feedback-Id
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# Received
# Received
# Content-Type
# Date
# From
# Mime-Version
# Message-ID
# Subject
# X-SG-EID
# X-SG-ID
# To
# X-Entity-ID
# List-Unsubscribe
# List-Unsubscribe-Post
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# From
# To
# Reply-To
# Precedence
# List-Unsubscribe
# List-Unsubscribe-Post
# Subject
# Date
# MIME-Version
# Content-Type
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# Return-Path
# Received
# X-Relaying-Domain
# Date
# To
# From
# Subject
# Message-ID
# X-Mailer
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Feedback-ID
# X-GoogleForms-FormId
# X-GoogleForms-CustomerDisplayName
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# MIME-Version
# X-Received
# Feedback-ID
# X-GoogleForms-FormId
# X-GoogleForms-CustomerDisplayName
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# Feedback-Id
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Reply-To
# X-No-Auto-Attachment
# References
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Forwarded-Encrypted
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# X-Google-DKIM-Signature
# X-Forwarded-Encrypted
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# X-BeenThere
# Received
# X-Forwarded-Encrypted
# X-Received
# X-BeenThere
# Received
# X-Received
# Date
# From
# To
# Message-Id
# Subject
# MIME-Version
# Content-Type
# X-Original-Sender
# Reply-To
# Precedence
# Mailing-list
# List-ID
# X-Spam-Checked-In-Group
# X-Google-Group-Id
# List-Post
# List-Help
# List-Archive
# List-Unsubscribe
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# Return-Path
# Received
# Message-ID
# Date
# X-Google-Original-Date
# MIME-Version
# From
# To
# Subject
# Content-Type
# Content-Transfer-Encoding
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# Received
# Received
# Content-Transfer-Encoding
# Content-Type
# Date
# From
# Mime-Version
# Message-ID
# Subject
# X-SG-EID
# X-SG-ID
# To
# X-Entity-ID
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailgun-Dkim
# Feedback-Id
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# Feedback-Id
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# References
# In-Reply-To
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# References
# In-Reply-To
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Reply-To
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# References
# In-Reply-To
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# Received
# Received
# Content-Type
# Date
# From
# Mime-Version
# Message-ID
# Subject
# X-SG-EID
# X-SG-ID
# To
# X-Entity-ID
# List-Unsubscribe
# List-Unsubscribe-Post
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# From
# To
# Precedence
# List-Unsubscribe
# List-Unsubscribe-Post
# Subject
# Date
# MIME-Version
# Content-Type
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Reply-To
# X-No-Auto-Attachment
# References
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# Received
# Received
# Content-Type
# Date
# From
# Mime-Version
# Message-ID
# Subject
# X-SG-EID
# X-SG-ID
# To
# X-Entity-ID
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# From
# To
# Reply-To
# Precedence
# List-Unsubscribe
# List-Unsubscribe-Post
# Subject
# Date
# MIME-Version
# Content-Type
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Track-Opens
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Report-Abuse-To
# X-Mailer
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# Feedback-Id
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Report-Abuse-To
# List-Unsubscribe
# X-Mailer
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# MIME-Version
# From
# To
# Date
# Subject
# Content-Type
# Content-Transfer-Encoding
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# MIME-Version
# From
# To
# Date
# Subject
# Content-Type
# Content-Transfer-Encoding
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailgun-Dkim
# X-Mailer
# X-Report-Abuse-To
# Feedback-Id
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# X-Account-Notification-Type
# Feedback-ID
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# Date
# To
# From
# Reply-To
# Subject
# Message-ID
# X-Priority
# X-Mailer
# X-Moodle-Originating-Script
# MIME-Version
# Content-Type
# X-AntiAbuse
# X-AntiAbuse
# X-AntiAbuse
# X-AntiAbuse
# X-AntiAbuse
# X-Get-Message-Sender-Via
# X-Authenticated-Sender
# X-Source
# X-Source-Args
# X-Source-Dir
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# X-MSFBL
# DKIM-Signature
# To
# Message-ID
# Date
# Content-Type
# MIME-Version
# Reply-To
# Subject
# X-Campaign-ID
# From
# X-Message-ID
# X-Feedback-ID
# Feedback-ID
# List-Unsubscribe
# List-Unsubscribe-Post
# List-Id
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# X-MSFBL
# DKIM-Signature
# To
# Message-ID
# Date
# Content-Type
# MIME-Version
# Reply-To
# Subject
# X-Campaign-ID
# From
# X-Message-ID
# X-Feedback-ID
# Feedback-ID
# List-Unsubscribe
# List-Unsubscribe-Post
# List-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# To
# From
# Reply-To
# Subject
# Message-ID
# X-Mailer
# List-Unsubscribe
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# X-MSFBL
# DKIM-Signature
# To
# Message-ID
# Date
# Content-Type
# MIME-Version
# Reply-To
# X-Campaign-ID
# From
# Subject
# X-Message-ID
# X-Feedback-ID
# Feedback-ID
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# X-Account-Notification-Type
# Feedback-ID
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# References
# In-Reply-To
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Sender
# Return-Path
# Date
# From
# Reply-To
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailgun-Tag
# X-Mailgun-Variables
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# X-Account-Notification-Type
# Feedback-ID
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# X-MSFBL
# DKIM-Signature
# To
# Message-ID
# Date
# Content-Type
# MIME-Version
# Reply-To
# Subject
# X-Campaign-ID
# From
# X-Message-ID
# X-Feedback-ID
# Feedback-ID
# List-Unsubscribe
# List-Unsubscribe-Post
# List-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# Received
# Received
# Date
# From
# Message-ID
# Subject
# MIME-Version
# X-SG-EID
# X-SG-ID
# To
# X-Entity-ID
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# Feedback-Id
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# Date
# To
# From
# Reply-To
# Subject
# Message-ID
# X-Priority
# X-Mailer
# X-Moodle-Originating-Script
# MIME-Version
# Content-Type
# X-AntiAbuse
# X-AntiAbuse
# X-AntiAbuse
# X-AntiAbuse
# X-AntiAbuse
# X-Get-Message-Sender-Via
# X-Authenticated-Sender
# X-Source
# X-Source-Args
# X-Source-Dir
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Report-Abuse-To
# Feedback-Id
# X-Mailer
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Reply-To
# X-No-Auto-Attachment
# References
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Reply-To
# X-No-Auto-Attachment
# References
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# Return-Path
# Received
# Message-ID
# Date
# X-Google-Original-Date
# MIME-Version
# From
# To
# Subject
# Content-Type
# Content-Transfer-Encoding
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# Received
# Received
# Received
# Date
# From
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-SG-EID
# To
# X-Entity-ID
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# Reply-To
# X-Google-Id
# Feedback-ID
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# References
# In-Reply-To
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Content-Type
# List-ID
# X-Auto-Response-Suppress
# X-Email-Type
# From
# To
# Reply-To
# Subject
# Message-ID
# Date
# MIME-Version
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Reply-To
# X-No-Auto-Attachment
# References
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# References
# In-Reply-To
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# ...
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# From
# To
# Reply-To
# Precedence
# List-Unsubscribe
# List-Unsubscribe-Post
# Subject
# Date
# MIME-Version
# Content-Type
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-CSA-Complaints
# X-Mailin-EID
# Date
# Reply-To
# List-Unsubscribe-Post
# From
# Feedback-ID
# To
# Subject
# X-sib-id
# Message-Id
# Origin-messageId
# List-Unsubscribe
# Mime-Version
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# X-Account-Notification-Type
# Feedback-ID
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# X-Account-Notification-Type
# Feedback-ID
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# X-MSFBL
# DKIM-Signature
# To
# Message-ID
# Date
# Content-Type
# MIME-Version
# Reply-To
# Subject
# X-Campaign-ID
# From
# X-Message-ID
# X-Feedback-ID
# Feedback-ID
# List-Unsubscribe
# List-Unsubscribe-Post
# List-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# X-Account-Notification-Type
# Feedback-ID
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Track-Opens
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# Feedback-Id
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailin-EID
# X-sib-id
# List-Unsubscribe-Post
# Feedback-ID
# From
# Message-Id
# X-CSA-Complaints
# Origin-messageId
# To
# Date
# Subject
# Reply-To
# List-Unsubscribe
# Mime-Version
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Reply-To
# X-No-Auto-Attachment
# References
# Message-ID
# Date
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# Date
# To
# From
# Reply-To
# Subject
# Message-ID
# X-Priority
# X-Mailer
# List-Id
# List-Help
# X-Course-Id
# X-Course-Name
# Precedence
# X-Auto-Response-Suppress
# Auto-Submitted
# List-Unsubscribe
# Thread-Topic
# Thread-Index
# X-Moodle-Originating-Script
# MIME-Version
# Content-Type
# X-AntiAbuse
# X-AntiAbuse
# X-AntiAbuse
# X-AntiAbuse
# X-AntiAbuse
# X-Get-Message-Sender-Via
# X-Authenticated-Sender
# X-Source
# X-Source-Args
# X-Source-Dir
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# X-Account-Notification-Type
# Feedback-ID
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# X-MSFBL
# DKIM-Signature
# To
# Message-ID
# Date
# Content-Type
# MIME-Version
# Reply-To
# Subject
# X-Campaign-ID
# From
# X-Message-ID
# X-Feedback-ID
# Feedback-ID
# List-Unsubscribe
# List-Unsubscribe-Post
# List-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Report-Abuse-To
# Feedback-Id
# X-Mailer
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# X-Mailer
# X-Report-Abuse-To
# Feedback-Id
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# Content-Type
# To
# Received
# Return-Path
# Auto-Submitted
# Message-ID
# Date
# From
# Subject
# References
# In-Reply-To
# X-Failed-Recipients
# X-GM-THRID
# X-Gmail-Labels
# MIME-Version
# Date
# Message-ID
# Subject
# From
# To
# Content-Type
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# Date
# X-CSA-Complaints
# To
# Subject
# Message-Id
# List-Unsubscribe-Post
# List-Unsubscribe
# Origin-messageId
# Feedback-ID
# From
# X-Mailin-EID
# X-sib-id
# Reply-To
# Content-Type
# Mime-Version
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# List-Unsubscribe
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Mailgun-Sending-Ip
# X-Mailgun-Sid
# Received
# Date
# Mime-Version
# Content-Type
# Subject
# From
# To
# X-Mailgun-Dkim
# X-Mailgun-Native-Send
# X-Mailgun-Track-Clicks
# X-Mailgun-Track-Opens
# Feedback-Id
# X-Mailer
# X-Report-Abuse-To
# X-Mailgun-Variables
# Message-Id
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Received
# DKIM-Signature
# Date
# From
# To
# Message-ID
# Subject
# Mime-Version
# Content-Type
# Content-Transfer-Encoding
# X-Auto-Response-Suppress
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# DKIM-Signature
# Date
# From
# List-Unsubscribe-Post
# List-Unsubscribe
# To
# Reply-To
# Subject
# Content-Type
# CAMPAIGN_ID
# MIME-VERSION
# Message-ID
# Feedback-ID
# X-SES-Outgoing
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# Message-ID
# DKIM-Signature
# thread-index
# Thread-Topic
# Reply-To
# From
# To
# Subject
# Date
# MIME-Version
# Content-Type
# Content-Transfer-Encoding
# X-Mailer
# Content-Class
# Importance
# Priority
# X-MimeOLE
# X-OriginalArrivalTime
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# Return-Path
# Received
# Message-ID
# Date
# X-Google-Original-Date
# MIME-Version
# From
# To
# Subject
# Content-Type
# Content-Transfer-Encoding
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# X-Received
# MIME-Version
# From
# Date
# Message-ID
# Subject
# To
# Content-Type

# %%
import csv

with open('mailbox.csv', 'w') as outputfile:
  writer = csv.writer(outputfile)
  writer.writerow(['subject','from','date','to','label','thread'])

  for message in mbox:
    writer.writerow([message['subject'], message['from'],  message['date'], message['to'],  message['X-Gmail-Labels'], message['X-GM-THRID']])

# %%
dfs = pd.read_csv('mailbox.csv', names=['subject', 'from', 'date', 'to', 'label', 'thread'])

# %%
dfs.dtypes
# Out:
# subject    object
# from       object
# date       object
# to         object
# label      object
# thread     object
# dtype: object

# %%
dfs['date'] = dfs['date'].apply(lambda x: pd.to_datetime(x, errors='coerce', utc=True))

# %%
dfs = dfs[dfs['date'].notna()]

# %%
dfs.to_csv('gmail.csv')

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 583 entries, 1 to 583
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   subject  521 non-null    object
#  1   from     583 non-null    object
#  2   date     583 non-null    datetime64[ns, UTC]
#  3   to       581 non-null    object
#  4   label    583 non-null    object
#  5   thread   583 non-null    object
# dtypes: datetime64[ns, UTC](1), object(5)
# memory usage: 31.9+ KB

# %%
dfs.head(10)
# Out:
#                                               subject  \
# 1                              Merchant Email Receipt
# 2        New Course: AWS Security and Cost Management
# 3                Gizmo Survey - chance to win a prize
# 4                  Folder shared with you: "Research"
# 5                              Merchant Email Receipt
# 6                              Merchant Email Receipt
# 7                             Factory reset requested
# 8   ISAT U VLE Notification You have submitted you...
# 9   =?UTF-8?B?VW5sb2NrIEV4Y2x1c2l2ZSBTYW1zdW5nICNZ...
# 10  [Free Download] Data & AI Trends & Predictions...
#
#                                                  from  \
# 1         "Auto-Receipt" <noreply@mail.authorize.net>
# 2               DataCamp Insights <team@datacamp.com>
# 3                         Gizmo <paul@email.gizmo.ai>
# 4   "MARIVIC AMUAN (via Google Drive)" <drive-shar...
# 5         "Auto-Receipt" <noreply@mail.authorize.net>
# 6         "Auto-Receipt" <noreply@mail.authorize.net>
# 7                 Find My Device <noreply@google.com>
# 8   "Do not reply to this email  (via ISAT U VLE)"...
# 9   Samsung Electronics Philippines <phillippines@...
# 10                       DataCamp <team@datacamp.com>
#
#                         date  \
# 1  2024-05-27 06:20:26+00:00
# 2  2024-06-11 19:19:01+00:00
# 3  2024-06-01 08:43:55+00:00
# 4  2024-09-03 05:27:26+00:00
# 5  2024-05-27 08:34:56+00:00
# 6  2024-05-27 07:45:14+00:00
# 7  2024-05-04 04:06:59+00:00
# 8  2024-08-30 04:00:26+00:00
# 9  2024-06-03 08:56:11+00:00
# 10 2024-08-28 19:01:57+00:00
#
#                                                    to  \
# 1   "TestFirstName TestLastName" <reyshamarie.sali...
# 2           reyshamarie.salinas@students.isatu.edu.ph
# 3         <reyshamarie.salinas@students.isatu.edu.ph>
# 4           reyshamarie.salinas@students.isatu.edu.ph
# 5   "TestFirstName TestLastName" <reyshamarie.sali...
# 6   "TestFirstName TestLastName" <reyshamarie.sali...
# 7           reyshamarie.salinas@students.isatu.edu.ph
# 8   "Reysha Marie SALINAS" <reyshamarie.salinas@st...
# 9   Reysha Salinas <reyshamarie.salinas@students.i...
# 10          reyshamarie.salinas@students.isatu.edu.ph
#
#                                        label               thread
# 1    Inbox,Important,Category Updates,Unread  1800185658638572153
# 2           Inbox,Opened,Category Promotions  1801593596993245307
# 3             Inbox,Category Personal,Unread  1800647670990934282
# 4              Inbox,Category Updates,Unread  1809151423673874036
# 5              Inbox,Category Updates,Unread  1800194120498780263
# 6              Inbox,Category Updates,Unread  1800190994136196010
# 7   Inbox,Important,Category Personal,Unread  1798093532095415902
# 8             Inbox,Opened,Category Personal  1808783561691029565
# 9           Inbox,Category Promotions,Unread  1800829638682227419
# 10          Inbox,Category Promotions,Unread  1808659087296132972

# %%
dfs.columns
# Out:
# Index(['subject', 'from', 'date', 'to', 'label', 'thread'], dtype='object')

# %%
dfs.shape
# Out:
# (583, 6)

# %%
import re

def extract_email_ID(string):
  email = re.findall(r'<(.+?)>', string)
  if not email:
    email = list(filter(lambda y: '@' in y, string.split()))
  return email[0] if email else np.nan

# %%
dfs['from'] = dfs['from'].apply(lambda x: extract_email_ID(x))

# %%
myemail = 'itsmeskm99@gmail.com'
dfs['label'] = dfs['from'].apply(lambda x: 'sent' if x==myemail else 'inbox')

# %%
dfs.drop(columns='to', inplace=True)

# %%
dfs.head(10)
# Out:
#                                               subject  \
# 1                              Merchant Email Receipt
# 2        New Course: AWS Security and Cost Management
# 3                Gizmo Survey - chance to win a prize
# 4                  Folder shared with you: "Research"
# 5                              Merchant Email Receipt
# 6                              Merchant Email Receipt
# 7                             Factory reset requested
# 8   ISAT U VLE Notification You have submitted you...
# 9   =?UTF-8?B?VW5sb2NrIEV4Y2x1c2l2ZSBTYW1zdW5nICNZ...
# 10  [Free Download] Data & AI Trends & Predictions...
#
#                                   from                      date  label  \
# 1           noreply@mail.authorize.net 2024-05-27 06:20:26+00:00  inbox
# 2                    team@datacamp.com 2024-06-11 19:19:01+00:00  inbox
# 3                  paul@email.gizmo.ai 2024-06-01 08:43:55+00:00  inbox
# 4   drive-shares-dm-noreply@google.com 2024-09-03 05:27:26+00:00  inbox
# 5           noreply@mail.authorize.net 2024-05-27 08:34:56+00:00  inbox
# 6           noreply@mail.authorize.net 2024-05-27 07:45:14+00:00  inbox
# 7                   noreply@google.com 2024-05-04 04:06:59+00:00  inbox
# 8              noreply@isatuvle.online 2024-08-30 04:00:26+00:00  inbox
# 9    phillippines@seao.crm.samsung.com 2024-06-03 08:56:11+00:00  inbox
# 10                   team@datacamp.com 2024-08-28 19:01:57+00:00  inbox
#
#                  thread
# 1   1800185658638572153
# 2   1801593596993245307
# 3   1800647670990934282
# 4   1809151423673874036
# 5   1800194120498780263
# 6   1800190994136196010
# 7   1798093532095415902
# 8   1808783561691029565
# 9   1800829638682227419
# 10  1808659087296132972

# %%
import datetime
import pytz

def refactor_timezone(x):
  est = pytz.timezone('US/Eastern')
  return x.astimezone(est)

# %%
dfs['date'] = dfs['date'].apply(lambda x: refactor_timezone(x))

# %%
dfs['dayofweek'] = dfs['date'].apply(lambda x: x.day_name()) # Use day_name() to get the day of the week from a Timestamp object
dfs['dayofweek'] = pd.Categorical(dfs['dayofweek'], categories=[
    'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
    'Saturday', 'Sunday'], ordered=True)

# %%
dfs['timeofday'] = dfs['date'].apply(lambda x: x.hour + x.minute/60 + x.second/3600)

# %%
dfs['hour'] = dfs['date'].apply(lambda x: x.hour)

# %%
dfs['year_int'] = dfs['date'].apply(lambda x: x.year)

# %%
dfs['year'] = dfs['date'].apply(lambda x: x.year + x.dayofyear/365.25)

# %%
dfs.index = dfs['date']
del dfs['date']

# %%
print(dfs.index.min().strftime('%a, %d %b %Y %I:%M %p'))
print(dfs.index.max().strftime('%a, %d %b %Y %I:%M %p'))

print(dfs['label'].value_counts())
# Out:
# Mon, 03 Oct 2022 10:54 AM
# Wed, 25 Sep 2024 08:17 PM
# label
# inbox    583
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
def plot_todo_vs_year(df, ax, color='C0', s=0.5, title=''):
  ind = np.zeros(len(df), dtype='bool')
  est = pytz.timezone('US/Eastern')

  df[~ind].plot.scatter('year', 'timeofday', s=s, alpha=0.6, ax=ax, color=color)
  ax.set_ylim(0, 24)
  ax.yaxis.set_major_locator(MaxNLocator(8))
  ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);

  ax.set_xlabel('')
  ax.set_ylabel('')
  ax.set_title(title)
  ax.grid(ls=':', color='k')

  return ax

# %%
sent = dfs[dfs['label']=='sent']
received = dfs[dfs['label']=='inbox']

# %%
fig, ax = plt.subplots(figsize=(18, 5))

plot_todo_vs_year(received, ax, title='Inbox')

plt.show()
# Out:
# <ipython-input-279-725e438063d6>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);

# %%
def plot_number_perday_per_year(df, ax, label=None, dt=0.3, **plot_kwargs):
    year = df[df['year'].notna()]['year'].values
    T = year.max() - year.min()
    bins = int(T / dt)
    weights = 1 / (np.ones_like(year) * dt * 365.25)
    ax.hist(year, bins=bins, weights=weights, label=label, **plot_kwargs);
    ax.grid(ls=':', color='k')

# %%
from scipy import ndimage

def plot_number_perdhour_per_year(df, ax, label=None, dt=1, smooth=False,
                      weight_fun=None, **plot_kwargs):

    tod = df[df['timeofday'].notna()]['timeofday'].values
    year = df[df['year'].notna()]['year'].values
    Ty = year.max() - year.min()
    T = tod.max() - tod.min()
    bins = int(T / dt)
    if weight_fun is None:
        weights = 1 / (np.ones_like(tod) * Ty * 365.25 / dt)
    else:
        weights = weight_fun(df)
    if smooth:
        hst, xedges = np.histogram(tod, bins=bins, weights=weights);
        x = np.delete(xedges, -1) + 0.5*(xedges[1] - xedges[0])
        hst = ndimage.gaussian_filter(hst, sigma=0.75)
        f = interp1d(x, hst, kind='cubic')
        x = np.linspace(x.min(), x.max(), 10000)
        hst = f(x)
        ax.plot(x, hst, label=label, **plot_kwargs)
    else:
        ax.hist(tod, bins=bins, weights=weights, label=label, **plot_kwargs);


    ax.grid(ls=':', color='k')
    orientation = plot_kwargs.get('orientation')
    if orientation is None or orientation == 'vertical':
        ax.set_xlim(0, 24)
        ax.xaxis.set_major_locator(MaxNLocator(8))
        ax.set_xticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")
                            for ts in ax.get_xticks()]);
    elif orientation == 'horizontal':
        ax.set_ylim(0, 24)
        ax.yaxis.set_major_locator(MaxNLocator(8))
        ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")
                            for ts in ax.get_yticks()]);

# %%
class TriplePlot:
  def __init__(self):
    gs = gridspec.GridSpec(6, 6)
    self.ax1 = plt.subplot(gs[2:6, :4])
    self.ax2 = plt.subplot(gs[2:6, 4:6], sharey=self.ax1)
    plt.setp(self.ax2.get_yticklabels(), visible=False);
    self.ax3 = plt.subplot(gs[:2, :4])
    plt.setp(self.ax3.get_xticklabels(), visible=False);

  def plot(self, df, color='darkblue', alpha=0.8, markersize=0.5, yr_bin=0.1, hr_bin=0.5):
    plot_todo_vs_year(df, self.ax1, color=color, s=markersize)
    plot_number_perdhour_per_year(df, self.ax2, dt=hr_bin, color=color, alpha=alpha, orientation='horizontal')
    self.ax2.set_xlabel('Average emails per hour')
    plot_number_perday_per_year(df, self.ax3, dt=yr_bin, color=color, alpha=alpha)
    self.ax3.set_ylabel('Average emails per day')

# %%
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

plt.figure(figsize=(12,12));
tpl = TriplePlot()

tpl.plot(received, color='C0', alpha=0.5)
tpl.plot(sent, color='C1', alpha=0.5)
p1 = mpatches.Patch(color='C0', label='Incoming', alpha=0.5)
p2 = mpatches.Patch(color='C1', label='Outgoing', alpha=0.5)
plt.legend(handles=[p1, p2], bbox_to_anchor=[1.45, 0.7], fontsize=14, shadow=True);
# Out:
# <ipython-input-279-725e438063d6>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);
# <ipython-input-286-fe9fa0c6dab1>:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")
# <ipython-input-279-725e438063d6>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p") for ts in ax.get_yticks()]);
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-288-219e33d27180> in <cell line: 8>()
#       6
#       7 tpl.plot(received, color='C0', alpha=0.5)
# ----> 8 tpl.plot(sent, color='C1', alpha=0.5)
#       9 p1 = mpatches.Patch(color='C0', label='Incoming', alpha=0.5)
#      10 p2 = mpatches.Patch(color='C1', label='Outgoing', alpha=0.5)
#
# <ipython-input-287-e80e8dd8fba7> in plot(self, df, color, alpha, markersize, yr_bin, hr_bin)
#      10   def plot(self, df, color='darkblue', alpha=0.8, markersize=0.5, yr_bin=0.1, hr_bin=0.5):
#      11     plot_todo_vs_year(df, self.ax1, color=color, s=markersize)
# ---> 12     plot_number_perdhour_per_year(df, self.ax2, dt=hr_bin, color=color, alpha=alpha, orientation='horizontal')
#      13     self.ax2.set_xlabel('Average emails per hour')
#      14     plot_number_perday_per_year(df, self.ax3, dt=yr_bin, color=color, alpha=alpha)
#
# <ipython-input-286-fe9fa0c6dab1> in plot_number_perdhour_per_year(df, ax, label, dt, smooth, weight_fun, **plot_kwargs)
#       6     tod = df[df['timeofday'].notna()]['timeofday'].values
#       7     year = df[df['year'].notna()]['year'].values
# ----> 8     Ty = year.max() - year.min()
#       9     T = tod.max() - tod.min()
#      10     bins = int(T / dt)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      39 def _amax(a, axis=None, out=None, keepdims=False,
#      40           initial=_NoValue, where=True):
# ---> 41     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      42
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
counts = dfs.dayofweek.value_counts(sort=False)
counts.plot(kind='bar')
# Out:
# <Axes: xlabel='dayofweek'>

# %%
addrs = received['from'].value_counts()

addrs[0:4]
# Out:
# from
# reyshamarie.salinas@students.isatu.edu.ph    90
# team@datacamp.com                            83
# marivic.amuan@students.isatu.edu.ph          59
# noreply@mail.authorize.net                   57
# Name: count, dtype: int64

# %%
def plot_number_perday_per_year(df, ax, label=None, dt=1.0, **plot_kwargs):
    year = df.index.year.values - df.index[0].year
    T = year.max() - year.min()
    bins = int(T / dt)
    if bins <= 0: # Check if bins is non-positive
        bins = 1  # Set bins to a minimum value of 1
    weights = 1 / (np.ones_like(year) * dt * 365.25)
    ax.hist(year, bins=bins, weights=weights, label=label, **plot_kwargs);
    ax.grid(ls=':', color='k')

# %%
#sdw = sent.groupby('dayofweek').size() / len(sent)
rdw = received.groupby('dayofweek').size() / len(received)

df_tmp = pd.DataFrame(data={'Outgoing Email': sdw, 'Incoming Email':rdw})
df_tmp.plot(kind='bar', rot=45, figsize=(8,5), alpha=0.5)
plt.xlabel('');
plt.ylabel('Fraction of weekly emails');
plt.grid(ls=':', color='k', alpha=0.5)
# Out:
# <ipython-input-295-9b9f33bb6f43>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rdw = received.groupby('dayofweek').size() / len(received)

# %%
import scipy.ndimage
from scipy.interpolate import interp1d

plt.figure(figsize=(8,5))
ax = plt.subplot(111)
for ct, dow in enumerate(dfs.dayofweek.cat.categories):
    df_r = received[received['dayofweek']==dow]
    weights = np.ones(len(df_r)) / len(received)
    wfun = lambda x: weights
    plot_number_perdhour_per_year(df_r, ax, dt=1, smooth=True, color=f'C{ct}',
                      alpha=0.8, lw=3, label=dow, weight_fun=wfun)

    df_s = sent[sent['dayofweek']==dow]
    # Check if df_s is empty and skip plotting if so
    if len(df_s) == 0:
        continue
    weights = np.ones(len(df_s)) / len(sent)
    wfun = lambda x: weights
    plot_number_perdhour_per_year(df_s, ax, dt=1, smooth=True, color=f'C{ct}',
                      alpha=0.8, lw=2, label=dow, ls='--', weight_fun=wfun)
ax.set_ylabel('Fraction of weekly emails per hour')
plt.legend(loc='upper left')
# Out:
# <ipython-input-286-fe9fa0c6dab1>:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([datetime.datetime.strptime(str(int(np.mod(ts, 24))), "%H").strftime("%I %p")

# %%
import scipy.ndimage
from scipy.interpolate import interp1d
from wordcloud import WordCloud

df_no_arxiv = dfs[dfs['from'] != 'no-reply@arXiv.org']
# It looks like you may have intended to use 'received' instead of 'inbox'
text = ' '.join(map(str, received['subject'].values))

# %%
stopwords = ['Re', 'Fwd', '3A_']
wrd = WordCloud(width=700, height=480, margin=0, collocations=False)
for sw in stopwords:
    wrd.stopwords.add(sw)
wordcloud = wrd.generate(text)

plt.figure(figsize=(25,15))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
